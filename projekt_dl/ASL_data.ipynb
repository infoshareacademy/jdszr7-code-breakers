# %% [markdown]
# # Sign-Language MNIST

# %% [markdown]
# ![American Sign Language](amer_sign2.png)

# %%
from tensorflow import keras
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization, AveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %%
! pip install opencv-python==4.6.0.66
# Out:
# Requirement already satisfied: opencv-python==4.6.0.66 in c:\users\xps\anaconda3\envs\isadl\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\xps\anaconda3\envs\isadl\lib\site-packages (from opencv-python==4.6.0.66) (1.22.3)

# %% [markdown]
# # Loading the ASL dataset

# %%
train_df = pd.read_csv("sign_mnist_train.csv")
test_df = pd.read_csv("sign_mnist_test.csv")

# %%
train_df.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %% [markdown]
# # Data Visualization and Preprocessing

# %%
plt.figure(figsize = (10,10)) # Label Count
sns.set_style("darkgrid")
sns.countplot(train_df['label'])
# Out:
# C:\Users\XPS\anaconda3\envs\isadl\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
y_train = train_df['label']
y_test = test_df['label']
del train_df['label']
del test_df['label']

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y_train = label_binarizer.fit_transform(y_train)
y_test = label_binarizer.fit_transform(y_test)

# %%
x_train = train_df.values
x_test = test_df.values

# %% [markdown]
# ### We perform a grayscale normalization to reduce the effect of illumination's differences.Moreover the CNN converges faster on [0..1] data than on [0..255].

# %%
# Normalize the data
x_train = x_train / 255
x_test = x_test / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
# Preview of first 10 images
f, ax = plt.subplots(2,5) 
f.set_size_inches(10, 10)
k = 0
for i in range(2):
    for j in range(5):
        ax[i,j].imshow(x_train[k].reshape(28, 28) , cmap = "gray")
        k += 1
    plt.tight_layout()

# %% [markdown]
# # Data Augmentation #1

# %%
datagen_1 = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=False,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = False, # Randomly zoom image 
        width_shift_range=False,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=False,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen_1.fit(x_train)

# %% [markdown]
# # Training the first simple model

# %%
model_1 = Sequential()

#model_1.add(Conv2D(128,kernel_size=(5,5), strides=1,padding='same',activation='relu',input_shape=(28,28,1)))
#model_1.add(MaxPool2D(pool_size=(3,3),strides=2,padding='same'))

model_1.add(Conv2D(64,kernel_size=(2,2), strides=1,activation='relu',input_shape=(28,28,1)))
model_1.add(MaxPool2D((2,2),2,padding='same'))

model_1.add(Conv2D(32,kernel_size=(2,2), strides=1,activation='relu',padding='same'))
model_1.add(MaxPool2D((2,2),2,padding='same'))

model_1.add(Flatten())

model_1.add(Dense(units=120, activation='relu'))
model_1.add(Dense(units=24, activation = 'softmax'))

model_1.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 27, 27, 64)        320
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 32)        8224
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  flatten_5 (Flatten)         (None, 1568)              0
#
#  dense_13 (Dense)            (None, 120)               188280
#
#  dense_14 (Dense)            (None, 24)                2904
#
# =================================================================
# Total params: 199,728
# Trainable params: 199,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
history_1 = model_1.fit(datagen_1.flow(x_train,y_train, batch_size = 128),
                    epochs = 20 , validation_data = (x_test, y_test))
# Out:
# Epoch 1/20
# 215/215 [==============================] - 10s 43ms/step - loss: 1.6933 - accuracy: 0.5089 - val_loss: 0.9544 - val_accuracy: 0.6808
# Epoch 2/20
# 215/215 [==============================] - 8s 39ms/step - loss: 0.3379 - accuracy: 0.9040 - val_loss: 0.6207 - val_accuracy: 0.8066
# Epoch 3/20
# 215/215 [==============================] - 9s 41ms/step - loss: 0.1082 - accuracy: 0.9758 - val_loss: 0.5846 - val_accuracy: 0.8339
# Epoch 4/20
# 215/215 [==============================] - 9s 40ms/step - loss: 0.0365 - accuracy: 0.9962 - val_loss: 0.5847 - val_accuracy: 0.8426
# Epoch 5/20
# 215/215 [==============================] - 9s 42ms/step - loss: 0.0162 - accuracy: 0.9995 - val_loss: 0.6669 - val_accuracy: 0.8554
# Epoch 6/20
# 215/215 [==============================] - 9s 40ms/step - loss: 0.0088 - accuracy: 0.9996 - val_loss: 0.6914 - val_accuracy: 0.8546
# Epoch 7/20
# 215/215 [==============================] - 10s 47ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.7155 - val_accuracy: 0.8603
# Epoch 8/20
# 215/215 [==============================] - 9s 43ms/step - loss: 0.0061 - accuracy: 0.9992 - val_loss: 0.7774 - val_accuracy: 0.8288
# Epoch 9/20
# 215/215 [==============================] - 10s 44ms/step - loss: 0.0097 - accuracy: 0.9980 - val_loss: 0.7489 - val_accuracy: 0.8613
# Epoch 10/20
# 215/215 [==============================] - 9s 43ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7463 - val_accuracy: 0.8740
# Epoch 11/20
# 215/215 [==============================] - 9s 40ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7516 - val_accuracy: 0.8713
# Epoch 12/20
# 215/215 [==============================] - 9s 40ms/step - loss: 9.0617e-04 - accuracy: 1.0000 - val_loss: 0.7748 - val_accuracy: 0.8680
# Epoch 13/20
# 215/215 [==============================] - 8s 39ms/step - loss: 7.0402e-04 - accuracy: 1.0000 - val_loss: 0.8018 - val_accuracy: 0.8740
# Epoch 14/20
# 215/215 [==============================] - 9s 41ms/step - loss: 5.7284e-04 - accuracy: 1.0000 - val_loss: 0.8030 - val_accuracy: 0.8688
# Epoch 15/20
# 215/215 [==============================] - 9s 42ms/step - loss: 7.2934e-04 - accuracy: 0.9999 - val_loss: 0.7710 - val_accuracy: 0.8730
# Epoch 16/20
# 215/215 [==============================] - 9s 41ms/step - loss: 0.0494 - accuracy: 0.9852 - val_loss: 0.7626 - val_accuracy: 0.8733
# Epoch 17/20
# 215/215 [==============================] - 9s 42ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7502 - val_accuracy: 0.8844
# Epoch 18/20
# 215/215 [==============================] - 9s 40ms/step - loss: 6.2195e-04 - accuracy: 1.0000 - val_loss: 0.7567 - val_accuracy: 0.8869
# Epoch 19/20
# 215/215 [==============================] - 9s 42ms/step - loss: 4.9098e-04 - accuracy: 1.0000 - val_loss: 0.7730 - val_accuracy: 0.8865
# Epoch 20/20
# 215/215 [==============================] - 9s 40ms/step - loss: 3.7659e-04 - accuracy: 1.0000 - val_loss: 0.7853 - val_accuracy: 0.8890

# %%
epochs = [i for i in range(20)]
fig , ax = plt.subplots(1,2)
train_acc = history_1.history['accuracy']
train_loss = history_1.history['loss']
val_acc = history_1.history['val_accuracy']
val_loss = history_1.history['val_loss']
fig.set_size_inches(16,9)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Testing Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()

# %%
metrics=pd.DataFrame(history_1.history)
metrics['epoch']=history_1.epoch
metrics
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 0   1.693265  0.508905  0.954390      0.680842      0
# 1   0.337894  0.904025  0.620713      0.806609      1
# 2   0.108174  0.975815  0.584628      0.833938      2
# 3   0.036515  0.996176  0.584653      0.842582      3
# 4   0.016218  0.999454  0.666861      0.855410      4
# 5   0.008843  0.999636  0.691357      0.854573      5
# 6   0.005136  1.000000  0.715514      0.860290      6
# 7   0.006068  0.999162  0.777429      0.828779      7
# 8   0.009683  0.997997  0.748949      0.861266      8
# 9   0.001526  1.000000  0.746258      0.873954      9
# 10  0.001152  1.000000  0.751623      0.871305     10
# 11  0.000906  1.000000  0.774770      0.867959     11
# 12  0.000704  1.000000  0.801812      0.873954     12
# 13  0.000573  1.000000  0.802985      0.868795     13
# 14  0.000729  0.999927  0.770979      0.872978     14
# 15  0.049436  0.985249  0.762648      0.873257     15
# 16  0.001093  1.000000  0.750203      0.884412     16
# 17  0.000622  1.000000  0.756731      0.886921     17
# 18  0.000491  1.000000  0.772978      0.886503     18
# 19  0.000377  1.000000  0.785285      0.889013     19

# %% [markdown]
# # Model 2 -- dropout 0.25

# %%
model_2 = Sequential()

model_2.add(Conv2D(128,kernel_size=(5,5), strides=1,padding='same',activation='relu',input_shape=(28,28,1)))
model_2.add(MaxPool2D(pool_size=(3,3),strides=2,padding='same'))

model_2.add(Conv2D(64,kernel_size=(2,2), strides=1,activation='relu', padding='same'))
model_2.add(MaxPool2D((2,2),2,padding='same'))

model_2.add(Conv2D(32,kernel_size=(2,2), strides=1,activation='relu',padding='same'))
model_2.add(MaxPool2D((2,2),2,padding='same'))

model_2.add(Flatten())

model_2.add(Dense(units=120, activation='relu'))
model_2.add(Dropout(rate=0.25))  # dropout
model_2.add(Dense(units=24, activation = 'softmax'))

model_2.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 28, 28, 128)       3328
#
#  max_pooling2d_14 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 64)        32832
#
#  max_pooling2d_15 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 7, 7, 32)          8224
#
#  max_pooling2d_16 (MaxPoolin  (None, 4, 4, 32)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 120)               61560
#
#  dropout_5 (Dropout)         (None, 120)               0
#
#  dense_20 (Dense)            (None, 24)                2904
#
# =================================================================
# Total params: 108,848
# Trainable params: 108,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

history_2 = model_2.fit(datagen_1.flow(x_train,y_train, batch_size = 128),
                    epochs = 20 , validation_data = (x_test, y_test))
# Out:
# Epoch 1/20
# 215/215 [==============================] - 20s 90ms/step - loss: 1.8669 - accuracy: 0.4248 - val_loss: 0.7166 - val_accuracy: 0.7674
# Epoch 2/20
# 215/215 [==============================] - 19s 90ms/step - loss: 0.4359 - accuracy: 0.8532 - val_loss: 0.4164 - val_accuracy: 0.8772
# Epoch 3/20
# 215/215 [==============================] - 20s 91ms/step - loss: 0.1878 - accuracy: 0.9377 - val_loss: 0.3128 - val_accuracy: 0.9063
# Epoch 4/20
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0983 - accuracy: 0.9683 - val_loss: 0.3212 - val_accuracy: 0.9120
# Epoch 5/20
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.2757 - val_accuracy: 0.9282
# Epoch 6/20
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0461 - accuracy: 0.9855 - val_loss: 0.2683 - val_accuracy: 0.9349
# Epoch 7/20
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.2775 - val_accuracy: 0.9342
# Epoch 8/20
# 215/215 [==============================] - 20s 92ms/step - loss: 0.0281 - accuracy: 0.9915 - val_loss: 0.3293 - val_accuracy: 0.9268
# Epoch 9/20
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0364 - accuracy: 0.9882 - val_loss: 0.3004 - val_accuracy: 0.9296
# Epoch 10/20
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.2911 - val_accuracy: 0.9289
# Epoch 11/20
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0249 - accuracy: 0.9913 - val_loss: 0.3263 - val_accuracy: 0.9334
# Epoch 12/20
# 215/215 [==============================] - 20s 93ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.2661 - val_accuracy: 0.9445
# Epoch 13/20
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.2172 - val_accuracy: 0.9439
# Epoch 14/20
# 215/215 [==============================] - 20s 92ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.2415 - val_accuracy: 0.9480
# Epoch 15/20
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.2796 - val_accuracy: 0.9342
# Epoch 16/20
# 215/215 [==============================] - 20s 94ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.3009 - val_accuracy: 0.9426
# Epoch 17/20
# 215/215 [==============================] - 20s 93ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.3411 - val_accuracy: 0.9441
# Epoch 18/20
# 215/215 [==============================] - 20s 92ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.3624 - val_accuracy: 0.9272
# Epoch 19/20
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.3793 - val_accuracy: 0.9377
# Epoch 20/20
# 215/215 [==============================] - 20s 94ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 0.3254 - val_accuracy: 0.9428

# %%
epochs = [i for i in range(20)]
fig , ax = plt.subplots(1,2)
train_acc = history_2.history['accuracy']
train_loss = history_2.history['loss']
val_acc = history_2.history['val_accuracy']
val_loss = history_2.history['val_loss']
fig.set_size_inches(16,9)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Testing Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()

# %%
metrics=pd.DataFrame(history_2.history)
metrics['epoch']=history_2.epoch
metrics
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 0   1.866869  0.424841  0.716624      0.767429      0
# 1   0.435871  0.853178  0.416433      0.877161      1
# 2   0.187756  0.937716  0.312763      0.906302      2
# 3   0.098327  0.968275  0.321232      0.912019      3
# 4   0.064224  0.980040  0.275750      0.928193      4
# 5   0.046129  0.985540  0.268262      0.934886      5
# 6   0.031413  0.990239  0.277511      0.934188      6
# 7   0.028106  0.991550  0.329260      0.926799      7
# 8   0.036406  0.988235  0.300383      0.929587      8
# 9   0.022685  0.993043  0.291053      0.928890      9
# 10  0.024898  0.991295  0.326269      0.933352     10
# 11  0.020775  0.993225  0.266108      0.944506     11
# 12  0.020763  0.992970  0.217241      0.943949     12
# 13  0.015231  0.995119  0.241494      0.947992     13
# 14  0.018813  0.993954  0.279637      0.934188     14
# 15  0.020029  0.993262  0.300873      0.942554     15
# 16  0.018918  0.993626  0.341120      0.944088     16
# 17  0.013705  0.995629  0.362365      0.927217     17
# 18  0.009480  0.997232  0.379315      0.937674     18
# 19  0.013388  0.995229  0.325401      0.942833     19

# %% [markdown]
# # Model 3 -- dropout , BatchNormalization

# %%
model_3 = Sequential()

model_3.add(Conv2D(128,kernel_size=(3,3), strides=1,padding='same',activation='relu',input_shape=(28,28,1)))
model_3.add(BatchNormalization())
model_3.add(MaxPool2D(pool_size=(2,2),strides=2,padding='same'))

model_3.add(Conv2D(64,kernel_size=(3,3), strides=1,activation='relu', padding='same'))
model_3.add(Dropout(0.2))
model_3.add(BatchNormalization())
model_3.add(MaxPool2D((2,2),2,padding='same'))

model_3.add(Conv2D(32,kernel_size=(3,3), strides=1,activation='relu',padding='same'))
model_3.add(MaxPool2D((2,2),2,padding='same'))

model_3.add(Flatten())

model_3.add(Dense(units=120, activation='relu'))
model_3.add(Dropout(rate=0.25))  # dropout
model_3.add(Dense(units=24, activation = 'softmax'))

model_3.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_39 (Conv2D)          (None, 28, 28, 128)       1280
#
#  batch_normalization_16 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  max_pooling2d_32 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 64)        73792
#
#  dropout_16 (Dropout)        (None, 14, 14, 64)        0
#
#  batch_normalization_17 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  max_pooling2d_33 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 7, 7, 32)          18464
#
#  max_pooling2d_34 (MaxPoolin  (None, 4, 4, 32)         0
#  g2D)
#
#  flatten_14 (Flatten)        (None, 512)               0
#
#  dense_31 (Dense)            (None, 120)               61560
#
#  dropout_17 (Dropout)        (None, 120)               0
#
#  dense_32 (Dense)            (None, 24)                2904
#
# =================================================================
# Total params: 158,768
# Trainable params: 158,384
# Non-trainable params: 384
# _________________________________________________________________

# %%
model_3.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

history_3 = model_3.fit(datagen_1.flow(x_train,y_train, batch_size = 128),
                    epochs = 20 , validation_data = (x_test, y_test))
# Out:
# Epoch 1/20
# 215/215 [==============================] - 35s 160ms/step - loss: 0.9200 - accuracy: 0.7202 - val_loss: 3.3222 - val_accuracy: 0.0534
# Epoch 2/20
# 215/215 [==============================] - 34s 159ms/step - loss: 0.0654 - accuracy: 0.9825 - val_loss: 1.9731 - val_accuracy: 0.5047
# Epoch 3/20
# 215/215 [==============================] - 34s 158ms/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.2230 - val_accuracy: 0.9272
# Epoch 4/20
# 215/215 [==============================] - 35s 161ms/step - loss: 0.0166 - accuracy: 0.9956 - val_loss: 0.3008 - val_accuracy: 0.8945
# Epoch 5/20
# 215/215 [==============================] - 35s 161ms/step - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.3836 - val_accuracy: 0.8935
# Epoch 6/20
# 215/215 [==============================] - 34s 159ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.2649 - val_accuracy: 0.9216
# Epoch 7/20
# 215/215 [==============================] - 34s 160ms/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.3107 - val_accuracy: 0.9067
# Epoch 8/20
# 215/215 [==============================] - 37s 171ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.2134 - val_accuracy: 0.9307
# Epoch 9/20
# 215/215 [==============================] - 35s 163ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 0.1365 - val_accuracy: 0.9615
# Epoch 10/20
# 215/215 [==============================] - 35s 164ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.2209 - val_accuracy: 0.9307
# Epoch 11/20
# 215/215 [==============================] - 35s 163ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.2549 - val_accuracy: 0.9357
# Epoch 12/20
# 215/215 [==============================] - 36s 169ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.1162 - val_accuracy: 0.9642
# Epoch 13/20
# 215/215 [==============================] - 35s 163ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.4578 - val_accuracy: 0.8889
# Epoch 14/20
# 215/215 [==============================] - 36s 166ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.1478 - val_accuracy: 0.9590
# Epoch 15/20
# 215/215 [==============================] - 36s 169ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 1.7107 - val_accuracy: 0.6963
# Epoch 16/20
# 215/215 [==============================] - 35s 164ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.3110 - val_accuracy: 0.9152
# Epoch 17/20
# 215/215 [==============================] - 36s 165ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.1945 - val_accuracy: 0.9586
# Epoch 18/20
# 215/215 [==============================] - 36s 166ms/step - loss: 9.0801e-04 - accuracy: 0.9998 - val_loss: 0.1437 - val_accuracy: 0.9656
# Epoch 19/20
# 215/215 [==============================] - 35s 164ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.6204 - val_accuracy: 0.8774
# Epoch 20/20
# 215/215 [==============================] - 35s 163ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1870 - val_accuracy: 0.9487

# %%
epochs = [i for i in range(20)]
fig , ax = plt.subplots(1,2)
train_acc = history_3.history['accuracy']
train_loss = history_3.history['loss']
val_acc = history_3.history['val_accuracy']
val_loss = history_3.history['val_loss']
fig.set_size_inches(16,9)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Testing Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()

# %%
metrics=pd.DataFrame(history_3.history)
metrics['epoch']=history_3.epoch
metrics
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 0   0.920037  0.720160  3.322219      0.053402      0
# 1   0.065410  0.982480  1.973129      0.504741      1
# 2   0.026844  0.992497  0.223009      0.927217      2
# 3   0.016628  0.995629  0.300768      0.894451      3
# 4   0.013737  0.996248  0.383635      0.893475      4
# 5   0.009533  0.997778  0.264881      0.921640      5
# 6   0.007988  0.997778  0.310711      0.906721      6
# 7   0.011338  0.996212  0.213413      0.930703      7
# 8   0.012559  0.996576  0.136474      0.961517      8
# 9   0.005956  0.998470  0.220901      0.930703      9
# 10  0.011948  0.996066  0.254857      0.935722     10
# 11  0.003786  0.998798  0.116214      0.964166     11
# 12  0.007326  0.997669  0.457828      0.888873     12
# 13  0.005904  0.997778  0.147793      0.959007     13
# 14  0.007400  0.997414  1.710702      0.696319     14
# 15  0.013474  0.995775  0.311016      0.915226     15
# 16  0.007389  0.997742  0.194477      0.958589     16
# 17  0.000908  0.999781  0.143685      0.965560     17
# 18  0.002348  0.999235  0.620356      0.877440     18
# 19  0.002340  0.999381  0.186987      0.948689     19

# %% [markdown]
# # Model 4 -- dropout, BatchNormalization, callbacks, dense (512)

# %%
callbacks = [EarlyStopping(patience=10, verbose=1, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.5, patience=2, min_lr=0.00001, verbose=1, monitor='val_accuracy'),
    ]

# %%
model_4 = Sequential()

model_4.add(Conv2D(128,kernel_size=(3,3), strides=1,padding='same',activation='relu',input_shape=(28,28,1)))
model_4.add(BatchNormalization())
model_4.add(MaxPool2D(pool_size=(2,2),strides=2,padding='same'))

model_4.add(Conv2D(64,kernel_size=(3,3), strides=1,activation='relu', padding='same'))
model_4.add(Dropout(0.2))
model_4.add(BatchNormalization())
model_4.add(MaxPool2D((2,2),2,padding='same'))

model_4.add(Conv2D(32,kernel_size=(3,3), strides=1,activation='relu',padding='same'))
model_4.add(MaxPool2D((2,2),2,padding='same'))

model_4.add(Flatten())

model_4.add(Dense(units=512, activation='relu'))
model_4.add(Dropout(rate=0.25))  # dropout
model_4.add(Dense(units=24, activation = 'softmax'))

model_4.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)       1280
#
#  batch_normalization_18 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  max_pooling2d_35 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 64)        73792
#
#  dropout_18 (Dropout)        (None, 14, 14, 64)        0
#
#  batch_normalization_19 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  max_pooling2d_36 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 7, 7, 32)          18464
#
#  max_pooling2d_37 (MaxPoolin  (None, 4, 4, 32)         0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 512)               0
#
#  dense_33 (Dense)            (None, 512)               262656
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_34 (Dense)            (None, 24)                12312
#
# =================================================================
# Total params: 369,272
# Trainable params: 368,888
# Non-trainable params: 384
# _________________________________________________________________

# %%
model_4.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

history_4 = model_4.fit(datagen_1.flow(x_train,y_train, batch_size = 128),
                    epochs = 20 , validation_data = (x_test, y_test), 
                    callbacks = [callbacks])
# Out:
# Epoch 1/20
# 215/215 [==============================] - 35s 159ms/step - loss: 0.5009 - accuracy: 0.8498 - val_loss: 4.0272 - val_accuracy: 0.0484 - lr: 0.0010
# Epoch 2/20
# 215/215 [==============================] - 36s 167ms/step - loss: 0.0131 - accuracy: 0.9972 - val_loss: 1.5339 - val_accuracy: 0.5243 - lr: 0.0010
# Epoch 3/20
# 215/215 [==============================] - 34s 160ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 0.2317 - val_accuracy: 0.9345 - lr: 0.0010
# Epoch 4/20
# 215/215 [==============================] - 35s 161ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1099 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 5/20
# 215/215 [==============================] - 35s 162ms/step - loss: 6.7231e-04 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9713 - lr: 0.0010
# Epoch 6/20
# 215/215 [==============================] - 36s 167ms/step - loss: 2.8783e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9716 - lr: 0.0010
# Epoch 7/20
# 215/215 [==============================] - 35s 164ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 3.3619 - val_accuracy: 0.4460 - lr: 0.0010
# Epoch 8/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9954
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 215/215 [==============================] - 35s 164ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.5596 - val_accuracy: 0.8401 - lr: 0.0010
# Epoch 9/20
# 215/215 [==============================] - 36s 167ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1192 - val_accuracy: 0.9695 - lr: 5.0000e-04
# Epoch 10/20
# 215/215 [==============================] - 36s 169ms/step - loss: 4.9082e-04 - accuracy: 0.9999 - val_loss: 0.0948 - val_accuracy: 0.9749 - lr: 5.0000e-04
# Epoch 11/20
# 215/215 [==============================] - 37s 170ms/step - loss: 1.4864e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9674 - lr: 5.0000e-04
# Epoch 12/20
# 215/215 [==============================] - ETA: 0s - loss: 1.9667e-04 - accuracy: 0.9999
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 215/215 [==============================] - 38s 178ms/step - loss: 1.9667e-04 - accuracy: 0.9999 - val_loss: 0.1168 - val_accuracy: 0.9689 - lr: 5.0000e-04
# Epoch 13/20
# 215/215 [==============================] - 36s 168ms/step - loss: 2.5797e-04 - accuracy: 0.9999 - val_loss: 0.1101 - val_accuracy: 0.9746 - lr: 2.5000e-04
# Epoch 14/20
# 215/215 [==============================] - ETA: 0s - loss: 7.2628e-05 - accuracy: 1.0000
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 215/215 [==============================] - 35s 164ms/step - loss: 7.2628e-05 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 0.9727 - lr: 2.5000e-04
# Epoch 15/20
# 215/215 [==============================] - ETA: 0s - loss: 7.6595e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 10.
# 215/215 [==============================] - 36s 168ms/step - loss: 7.6595e-05 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9720 - lr: 1.2500e-04
# Epoch 15: early stopping

# %%
epochs = [i for i in range(15)]
fig , ax = plt.subplots(1,2)
train_acc = history_4.history['accuracy']
train_loss = history_4.history['loss']
val_acc = history_4.history['val_accuracy']
val_loss = history_4.history['val_loss']
fig.set_size_inches(16,9)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Testing Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()

# %% [markdown]
# # Training The Final Model

# %% [markdown]
# In order to avoid overfitting problem, we need to expand artificially our dataset. We can make your existing dataset even larger. The idea is to alter the training data with small transformations to reproduce the variations.
#
# Approaches that alter the training data in ways that change the array representation while keeping the label the same are known as data augmentation techniques. Some popular augmentations people use are grayscales, horizontal flips, vertical flips, random crops, color jitters, translations, rotations, and much more.
#
# By applying just a couple of these transformations to our training data, we can easily double or triple the number of training examples and create a very robust model.

# %% [markdown]
# For the data augmentation, i choosed to :
#
# Randomly rotate some training images by 10 degrees Randomly Zoom by 10% some training images Randomly shift images horizontally by 10% of the width Randomly shift images vertically by 10% of the height I did not apply a vertical_flip nor horizontal_flip since it could have lead to misclassify.
#
# Once our model is ready, we fit the training dataset .

# %%
datagen_2 = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen_2.fit(x_train)

# %%
model_5 = Sequential()

model_5.add(Conv2D(128,kernel_size=(3,3), strides=1,padding='same',activation='relu',input_shape=(28,28,1)))
model_5.add(BatchNormalization())
model_5.add(MaxPool2D(pool_size=(2,2),strides=2,padding='same'))

model_5.add(Conv2D(64,kernel_size=(3,3), strides=1,activation='relu', padding='same'))
model_5.add(Dropout(0.2))
model_5.add(BatchNormalization())
model_5.add(MaxPool2D((2,2),2,padding='same'))

model_5.add(Conv2D(32,kernel_size=(3,3), strides=1,activation='relu',padding='same'))
model_5.add(MaxPool2D((2,2),2,padding='same'))

model_5.add(Flatten())

model_5.add(Dense(units=512, activation='relu'))
model_5.add(Dropout(rate=0.25))  # dropout
model_5.add(Dense(units=24, activation = 'softmax'))

model_5.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_45 (Conv2D)          (None, 28, 28, 128)       1280
#
#  batch_normalization_20 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  max_pooling2d_38 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 64)        73792
#
#  dropout_20 (Dropout)        (None, 14, 14, 64)        0
#
#  batch_normalization_21 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  max_pooling2d_39 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 7, 7, 32)          18464
#
#  max_pooling2d_40 (MaxPoolin  (None, 4, 4, 32)         0
#  g2D)
#
#  flatten_16 (Flatten)        (None, 512)               0
#
#  dense_35 (Dense)            (None, 512)               262656
#
#  dropout_21 (Dropout)        (None, 512)               0
#
#  dense_36 (Dense)            (None, 24)                12312
#
# =================================================================
# Total params: 369,272
# Trainable params: 368,888
# Non-trainable params: 384
# _________________________________________________________________

# %%
model_5.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

history_5 = model_5.fit(datagen_2.flow(x_train,y_train, batch_size = 128),
                    epochs = 20 , validation_data = (x_test, y_test), 
                    callbacks = [callbacks])
# Out:
# Epoch 1/20
# 215/215 [==============================] - 37s 168ms/step - loss: 0.0430 - accuracy: 0.9854 - val_loss: 0.0476 - val_accuracy: 0.9810 - lr: 0.0010
# Epoch 2/20
# 215/215 [==============================] - 34s 159ms/step - loss: 0.0359 - accuracy: 0.9872 - val_loss: 0.0229 - val_accuracy: 0.9908 - lr: 0.0010
# Epoch 3/20
# 215/215 [==============================] - 36s 168ms/step - loss: 0.0320 - accuracy: 0.9894 - val_loss: 0.0356 - val_accuracy: 0.9890 - lr: 0.0010
# Epoch 4/20
# 215/215 [==============================] - 36s 166ms/step - loss: 0.0231 - accuracy: 0.9922 - val_loss: 0.0094 - val_accuracy: 0.9976 - lr: 0.0010
# Epoch 5/20
# 215/215 [==============================] - 38s 176ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.2396 - val_accuracy: 0.9215 - lr: 0.0010
# Epoch 6/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9937
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 215/215 [==============================] - 38s 174ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.0345 - val_accuracy: 0.9888 - lr: 0.0010
# Epoch 7/20
# 215/215 [==============================] - 38s 178ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0226 - val_accuracy: 0.9915 - lr: 5.0000e-04
# Epoch 8/20
# 215/215 [==============================] - 38s 177ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0062 - val_accuracy: 0.9986 - lr: 5.0000e-04
# Epoch 9/20
# 215/215 [==============================] - 37s 171ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0140 - val_accuracy: 0.9961 - lr: 5.0000e-04
# Epoch 10/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9977
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 215/215 [==============================] - 38s 174ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0375 - val_accuracy: 0.9905 - lr: 5.0000e-04
# Epoch 11/20
# 215/215 [==============================] - 38s 175ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0127 - val_accuracy: 0.9972 - lr: 2.5000e-04
# Epoch 12/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9990
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 215/215 [==============================] - 37s 171ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0032 - val_accuracy: 0.9985 - lr: 2.5000e-04
# Epoch 13/20
# 215/215 [==============================] - 38s 174ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0062 - val_accuracy: 0.9967 - lr: 1.2500e-04
# Epoch 14/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 215/215 [==============================] - 38s 178ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0032 - val_accuracy: 0.9980 - lr: 1.2500e-04
# Epoch 15/20
# 215/215 [==============================] - 38s 175ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0042 - val_accuracy: 0.9974 - lr: 6.2500e-05
# Epoch 16/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 215/215 [==============================] - 38s 175ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0054 - val_accuracy: 0.9969 - lr: 6.2500e-05
# Epoch 17/20
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0080 - val_accuracy: 0.9972 - lr: 3.1250e-05
# Epoch 18/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 215/215 [==============================] - 37s 172ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0053 - val_accuracy: 0.9972 - lr: 3.1250e-05
# Epoch 19/20
# 215/215 [==============================] - 38s 176ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0077 - val_accuracy: 0.9972 - lr: 1.5625e-05
# Epoch 20/20
# 215/215 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-05.
# 215/215 [==============================] - 38s 174ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0071 - val_accuracy: 0.9974 - lr: 1.5625e-05

# %%
epochs = [i for i in range(20)]
fig , ax = plt.subplots(1,2)
train_acc = history_5.history['accuracy']
train_loss = history_5.history['loss']
val_acc = history_5.history['val_accuracy']
val_loss = history_5.history['val_loss']
fig.set_size_inches(16,9)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Testing Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()
